# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.linear_model import LogisticRegression

# %%
from proj1_helpers import *
from implementations import *

# %%
labels, features, ids = load_csv_data('train.csv')

# %%
train = pd.read_csv('train.csv', index_col = 0)
train.head(8)
# Out:
#        Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# Id
# 100000          s       138.470                       51.655        97.827
# 100001          b       160.937                       68.768       103.235
# 100002          b      -999.000                      162.172       125.953
# 100003          b       143.905                       81.417        80.943
# 100004          b       175.864                       16.915       134.805
# 100005          b        89.744                       13.550        59.149
# 100006          s       148.754                       28.862       107.782
# 100007          s       154.916                       10.418        94.714
#
#         DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# Id
# 100000    27.980                 0.910           124.711                2.666
# 100001    48.146              -999.000          -999.000             -999.000
# 100002    35.635              -999.000          -999.000             -999.000
# 100003     0.414              -999.000          -999.000             -999.000
# 100004    16.405              -999.000          -999.000             -999.000
# 100005   116.344                 2.636           284.584               -0.540
# 100006   106.130                 0.733           158.359                0.113
# 100007    29.169              -999.000          -999.000             -999.000
#
#         DER_deltar_tau_lep  DER_pt_tot       ...        PRI_met_phi  \
# Id                                           ...
# 100000               3.064      41.928       ...             -0.277
# 100001               3.473       2.078       ...             -1.916
# 100002               3.148       9.336       ...             -2.186
# 100003               3.310       0.414       ...              0.060
# 100004               3.891      16.405       ...             -0.871
# 100005               1.362      61.619       ...              2.237
# 100006               2.941       2.545       ...             -1.443
# 100007               2.897       1.526       ...             -1.761
#
#         PRI_met_sumet  PRI_jet_num  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# Id
# 100000        258.733            2              67.435                2.150
# 100001        164.546            1              46.226                0.725
# 100002        260.414            1              44.251                2.053
# 100003         86.062            0            -999.000             -999.000
# 100004         53.131            0            -999.000             -999.000
# 100005        282.849            3              90.547               -2.412
# 100006        294.074            2             123.010                0.864
# 100007        187.299            1              30.638               -0.715
#
#         PRI_jet_leading_phi  PRI_jet_subleading_pt  PRI_jet_subleading_eta  \
# Id
# 100000                0.444                 46.062                   1.240
# 100001                1.158               -999.000                -999.000
# 100002               -2.028               -999.000                -999.000
# 100003             -999.000               -999.000                -999.000
# 100004             -999.000               -999.000                -999.000
# 100005               -0.653                 56.165                   0.224
# 100006                1.450                 56.867                   0.131
# 100007               -1.724               -999.000                -999.000
#
#         PRI_jet_subleading_phi  PRI_jet_all_pt
# Id
# 100000                  -2.475         113.497
# 100001                -999.000          46.226
# 100002                -999.000          44.251
# 100003                -999.000           0.000
# 100004                -999.000           0.000
# 100005                   3.106         193.660
# 100006                  -2.767         179.877
# 100007                -999.000          30.638
#
# [8 rows x 31 columns]

# %%
train['Prediction'] = train['Prediction'].replace({'s': 1, 'b': -1})

# %%
#idx = train[train['PRI_jet_all_pt'] == 0].index
#train = train.drop(idx)

# %%
feature_selected = train.drop(columns = ['DER_deltaeta_jet_jet', 
                                         'DER_lep_eta_centrality', 
                                         'DER_prodeta_jet_jet', 
                                         'PRI_jet_leading_eta', 
                                         'DER_mass_jet_jet', 
                                         'PRI_jet_leading_phi',
                                         'PRI_jet_num',
                                        'PRI_jet_subleading_eta',
                                        'PRI_jet_subleading_phi',
                                        'PRI_jet_subleading_pt',
                                        'PRI_lep_eta',
                                        'PRI_lep_phi',
                                        'PRI_met_phi',
                                        'PRI_tau_eta',
                                        'PRI_tau_phi',
                                        'PRI_jet_all_pt'])

# %%
feature_selected.count()
# Out:
# Prediction                     150087
# DER_mass_MMC                   150087
# DER_mass_transverse_met_lep    150087
# DER_mass_vis                   150087
# DER_pt_h                       150087
# DER_deltar_tau_lep             150087
# DER_pt_tot                     150087
# DER_sum_pt                     150087
# DER_pt_ratio_lep_tau           150087
# DER_met_phi_centrality         150087
# PRI_tau_pt                     150087
# PRI_lep_pt                     150087
# PRI_met                        150087
# PRI_met_sumet                  150087
# PRI_jet_leading_pt             150087
# PRI_jet_all_pt                 150087
# dtype: int64

# %%
median_mass_MMC = np.median(feature_selected.DER_mass_MMC[feature_selected.DER_mass_MMC != -999])

# %%
feature_selected['DER_mass_MMC'] = feature_selected['DER_mass_MMC'].replace({-999: median_mass_MMC})

# %%
feature_selected.head()
# Out:
#         Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# Id
# 100000           1       138.470                       51.655        97.827
# 100001          -1       160.937                       68.768       103.235
# 100002          -1       112.831                      162.172       125.953
# 100005          -1        89.744                       13.550        59.149
# 100006           1       148.754                       28.862       107.782
#
#         DER_pt_h  DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  \
# Id
# 100000    27.980               3.064      41.928     197.760
# 100001    48.146               3.473       2.078     125.157
# 100002    35.635               3.148       9.336     197.814
# 100005   116.344               1.362      61.619     278.876
# 100006   106.130               2.941       2.545     305.967
#
#         DER_pt_ratio_lep_tau  DER_met_phi_centrality  PRI_tau_pt  PRI_lep_pt  \
# Id
# 100000                 1.582                   1.396      32.638      51.626
# 100001                 0.879                   1.414      42.014      36.918
# 100002                 3.776                   1.414      32.154     121.409
# 100005                 0.588                   0.479      53.651      31.565
# 100006                 3.371                   1.393      28.850      97.240
#
#         PRI_met  PRI_met_sumet  PRI_jet_leading_pt  PRI_jet_all_pt
# Id
# 100000   16.824        258.733              67.435         113.497
# 100001   44.704        164.546              46.226          46.226
# 100002   54.283        260.414              44.251          44.251
# 100005   40.735        282.849              90.547         193.660
# 100006   38.421        294.074             123.010         179.877

# %%
feature_selected.to_excel('/Users/wentao/Desktop/ML Project 1/feature_selected.xlsx')

# %%
feature_selected.describe()
# Out:
#           Prediction   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  150087.000000  150087.000000                150087.000000
# mean       -0.198132     121.722777                    42.884762
# std         0.980179      57.654549                    36.028021
# min        -1.000000       9.806000                     0.000000
# 25%        -1.000000      94.566000                    13.958000
# 50%        -1.000000     112.831000                    34.806000
# 75%         1.000000     132.398000                    65.157500
# max         1.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltar_tau_lep     DER_pt_tot  \
# count  150087.000000  150087.000000       150087.000000  150087.000000
# mean       80.723762      87.234780            2.178808      22.308055
# std        42.575765      66.412457            0.778822      24.748900
# min         6.329000       0.000000            0.208000       0.000000
# 25%        58.469500      42.135500            1.594000       3.425000
# 50%        72.557000      67.630000            2.208000      18.231000
# 75%        90.913000     111.598000            2.759000      31.004500
# max      1329.913000    1053.807000            5.655000     513.659000
#
#           DER_sum_pt  DER_pt_ratio_lep_tau  DER_met_phi_centrality  \
# count  150087.000000         150087.000000           150087.000000
# mean      213.056414              1.467463                0.392121
# std       120.269295              0.980422                1.054153
# min        77.017000              0.047000               -1.414000
# 25%       129.789500              0.823000               -0.598000
# 50%       178.643000              1.246000                0.903000
# 75%       257.436000              1.825000                1.330000
# max      1852.462000             19.773000                1.414000
#
#           PRI_tau_pt     PRI_lep_pt        PRI_met  PRI_met_sumet  \
# count  150087.000000  150087.000000  150087.000000  150087.000000
# mean       41.832681      49.520003      48.494382     265.673665
# std        25.648489      25.473017      37.593736     130.255341
# min        20.000000      26.000000       0.200000      21.066000
# 25%        25.507500      32.780000      24.297000     176.799000
# 50%        33.874000      41.844000      39.470000     236.984000
# 75%        48.957000      57.487000      61.028000     321.399500
# max       622.862000     461.896000     951.363000    2003.976000
#
#        PRI_jet_leading_pt  PRI_jet_all_pt
# count       150087.000000   150087.000000
# mean            84.822105      121.703731
# std             60.662276      100.413845
# min             30.000000       30.000000
# 25%             44.422500       48.947000
# 50%             65.561000       91.762000
# 75%            103.342000      159.062000
# max           1120.573000     1633.433000

# %%
bin_feature_selected = (feature_selected - feature_selected.describe().loc['mean']) / feature_selected.describe().loc['std']
bin_feature_selected['Prediction'] = feature_selected['Prediction']

# %%
bin_feature_selected = sigmoid_compute(bin_feature_selected)
bin_feature_selected['Prediction'] = feature_selected['Prediction']

# %%
bin_feature_selected.describe()
# Out:
#           Prediction   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  150087.000000  150087.000000                150087.000000
# mean       -0.198132      -0.034878                    -0.022624
# std         0.980179       0.309176                     0.398611
# min        -1.000000      -0.748959                    -0.533595
# 25%        -1.000000      -0.231253                    -0.381187
# 50%        -1.000000      -0.076960                    -0.111650
# 75%         1.000000       0.092316                     0.299621
# max         1.000000       1.000000                     1.000000
#
#         DER_mass_vis       DER_pt_h  DER_deltar_tau_lep     DER_pt_tot  \
# count  150087.000000  150087.000000       150087.000000  150087.000000
# mean       -0.034594      -0.033585           -0.000399      -0.032210
# std         0.324329       0.373078            0.422013       0.365767
# min        -0.703236      -0.576207           -0.852505      -0.422464
# 25%        -0.255557      -0.327066           -0.358744      -0.364003
# 50%        -0.095616      -0.146536            0.018739      -0.082183
# 75%         0.119092       0.181394            0.356160       0.173908
# max         1.000000       0.999999            0.977216       1.000000
#
#           DER_sum_pt  DER_pt_ratio_lep_tau  DER_met_phi_centrality  \
# count  150087.000000         150087.000000           150087.000000
# mean       -0.033764             -0.030915                0.019745
# std         0.370442              0.366004                0.439396
# min        -0.512092             -0.619636               -0.694538
# 25%        -0.332973             -0.317322               -0.437899
# 50%        -0.142100             -0.112465                0.237683
# 75%         0.182436              0.180344                0.417656
# max         0.999998              1.000000                0.449993
#
#           PRI_tau_pt     PRI_lep_pt        PRI_met  PRI_met_sumet  \
# count  150087.000000  150087.000000  150087.000000  150087.000000
# mean       -0.036862      -0.035838      -0.033044      -0.028087
# std         0.344806       0.355018       0.360900       0.381729
# min        -0.401649      -0.431440      -0.566477      -0.734742
# 25%        -0.307922      -0.317247      -0.311158      -0.328509
# 50%        -0.153916      -0.149539      -0.119452      -0.109685
# 75%         0.137998       0.155119       0.165171       0.210706
# max         1.000000       1.000000       1.000000       0.999997
#
#        PRI_jet_leading_pt  PRI_jet_all_pt
# count       150087.000000   150087.000000
# mean            -0.036903       -0.034220
# std              0.359082        0.369059
# min             -0.423429       -0.427333
# 25%             -0.321203       -0.347225
# 50%             -0.157436       -0.147997
# 75%              0.151473        0.183905
# max              1.000000        0.999999

# %%
#bin_feature_selected.to_excel('/Users/wentao/Desktop/processed_training.xlsx')
feature_selected.head()
# Out:
#         Prediction  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# Id
# 100000           1       138.470                       51.655        97.827
# 100001          -1       160.937                       68.768       103.235
# 100002          -1       112.831                      162.172       125.953
# 100005          -1        89.744                       13.550        59.149
# 100006           1       148.754                       28.862       107.782
#
#         DER_pt_h  DER_deltar_tau_lep  DER_pt_tot  DER_sum_pt  \
# Id
# 100000    27.980               3.064      41.928     197.760
# 100001    48.146               3.473       2.078     125.157
# 100002    35.635               3.148       9.336     197.814
# 100005   116.344               1.362      61.619     278.876
# 100006   106.130               2.941       2.545     305.967
#
#         DER_pt_ratio_lep_tau  DER_met_phi_centrality  PRI_tau_pt  PRI_lep_pt  \
# Id
# 100000                 1.582                   1.396      32.638      51.626
# 100001                 0.879                   1.414      42.014      36.918
# 100002                 3.776                   1.414      32.154     121.409
# 100005                 0.588                   0.479      53.651      31.565
# 100006                 3.371                   1.393      28.850      97.240
#
#         PRI_met  PRI_met_sumet  PRI_jet_leading_pt  PRI_jet_all_pt
# Id
# 100000   16.824        258.733              67.435         113.497
# 100001   44.704        164.546              46.226          46.226
# 100002   54.283        260.414              44.251          44.251
# 100005   40.735        282.849              90.547         193.660
# 100006   38.421        294.074             123.010         179.877

# %%
X = feature_selected.drop(columns='Prediction')
y = feature_selected['Prediction']

clf = LogisticRegression(max_iter = 1000).fit(X, y)

# %%
clf.score(X, y)
# Out:
# 0.6939774930540287

# %%
test = pd.read_csv('test.csv', index_col= 0)

# %%
test_selected = test.drop(columns = ['DER_deltaeta_jet_jet', 
                                         'DER_lep_eta_centrality', 
                                         'DER_prodeta_jet_jet', 
                                         'PRI_jet_leading_eta', 
                                         'DER_mass_jet_jet', 
                                         'PRI_jet_leading_phi',
                                         'PRI_jet_num',
                                        'PRI_jet_subleading_eta',
                                        'PRI_jet_subleading_phi',
                                        'PRI_jet_subleading_pt',
                                        'PRI_lep_eta',
                                        'PRI_lep_phi',
                                        'PRI_met_phi',
                                        'PRI_tau_eta',
                                        'PRI_tau_phi'])
median_mass_MMC = np.median(test.DER_mass_MMC[test.DER_mass_MMC != -999])
test['DER_mass_MMC'] = test['DER_mass_MMC'].replace({-999: median_mass_MMC})

# %%
predict_label = clf.predict(test_selected.drop(columns='Prediction'))

# %%
sub = pd.read_csv('sample-submission.csv', index_col=0)

# %%
sub.Prediction = predict_label

# %%
pd.DataFrame.to_csv(sub, 'sub.csv')
